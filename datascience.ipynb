# %%
a = 2

# %%
b = 44

# %%
print(a+b)
# Out:
# 143

# %%
a2 = 99

# %%
print= 9

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 print(a)
#
# TypeError: 'int' object is not callable

# %%
del print

# %%
print(a)
# Out:
# 99

# %%
name = a

# %%
print(name)
# Out:
# 99

# %%
name = "h"

# %%
print(name)
# Out:
# h

# %%
print(name + str(a))
# Out:
# h99

# %%
type(name)
# Out:
# str

# %%
z = '4'

# %%
print(int(z) + a)
# Out:
# 103

# %%
z = int(z)

# %%
type(z)
# Out:
# int

# %%
input()
# Out:
#  king
# 'king'

# %%
x = int(input())
y = int(input())
print(x+ y)
# Out:
#  33
#  66
# 99

# %%
z= input()
# Out:
#  77

# %%
z
# Out:
# '77'

# %%
city = 'hello,hii,bye '

# %%
city
# Out:
# 'hello,hii,bye '

# %%
cities = '''hello
hii
bye '''

# %%
print(cities)
# Out:
# hello
# hii
# bye

# %%
cities1 = 'hello\thii'

# %%
print(cities1)
# Out:
# hello	hii

# %%
city1 = r'hello\world\queen\rock\nap'
#use r for raw to tell python to treat \ as simple literal

# %%
print(city1)
# Out:
# hello\world\queen\rock\nap

# %%
value = '\u0908\u0936\u093E'
#https://jrgraphix.net

# %%
print(value)
# Out:
# ईशा
