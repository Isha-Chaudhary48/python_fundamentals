# %%
#list datatype

# %%
list1= []

# %%
type(list1)
# Out:
# list

# %%
list2 = ['king','queen','hello',1,33,'hii']

# %%
print(list2)
# Out:
# ['king', 'queen', 'hello', 1, 33, 'hii']

# %%
print(list2[1])
# Out:
# queen

# %%
## Negative indexing if -1 will give last element helpful in large lists

# %%
print(list2[-1])
# Out:
# hii

# %%
# slicing

# %%
print(list2[1:3])
# Out:
# ['queen', 'hello']

# %%
print(list2[:5])
# Out:
# ['king', 'queen', 'hello', 1, 33]

# %%
print(list2[3:])
# Out:
# [1, 33, 'hii']

# %%
list2[2] = 'leaf'

# %%
print(list2)
# Out:
# ['king', 'queen', 'leaf', 1, 33, 'hii']

# %%
## Index method

# %%
list2.index('leaf')
# Out:
# 2

# %%
# if any duplicate value then we can specify from where to start and end searching in the list
lists=['king', 'queen', 'hello', 1, 33,'queen','hii','yes','queen']

# %%
lists.index('queen',2)
# Out:
# 5

# %%
lists.index('queen',6,9)
# Out:
# 8

# %%
# count method

# %%
lists.count('queen')
# Out:
# 3

# %%
# sorting method

# %%
list3 = [56,23,87,3,54,90,1,34,5]

# %%
list3.sort()

# %%
print(list3)
# Out:
# [1, 3, 5, 23, 34, 54, 56, 87, 90]

# %%
# reverse sorting
list3.sort(reverse = True)

# %%
print(list3)
# Out:
# [90, 87, 56, 54, 34, 23, 5, 3, 1, 'asus', 'asus', 'hii', 'hii']

# %%
# append  method problem i was using ctrl + enter that is running same cell twice

# %%
list3.append('hii')

# %%
print(list3)
# Out:
# [90, 87, 56, 54, 34, 23, 5, 3, 1, 'asus', 'asus', 'asus', 'asus', 'hii', 'hii']

# %%
print(list3)
# Out:
# [90, 87, 56, 54, 34, 23, 5, 3, 1, 'asus', 'asus', 'asus', 'asus', 'hii', 'hii']

# %%
# remove method

# %%
list3.remove('asus')

# %%
print(list3)
# Out:
# [90, 87, 56, 'hello', 54, 34, 23, 5, 3, 1, 'asus', 2, 3, 4]

# %%
# pop method

# %%
list3.pop(11)
# Out:
# 'hii'

# %%
list3
# Out:
# [90, 87, 56, 54, 34, 23, 5, 3, 1, 'asus', 'asus']

# %%
# extend method : if want to addon more elements

# %%
list3.extend([2,3,4])

# %%
print(list3)
# Out:
# [90, 87, 56, 54, 34, 23, 5, 3, 1, 'asus', 'asus', 2, 3, 4]

# %%
# insert method

# %%
list3.insert(3,'hello')

# %%
print(list3)
# Out:
# [90, 87, 56, 'hello', 54, 34, 23, 5, 3, 1, 'asus', 2, 3, 4]

# %%
# insert list inside list

# %%
list3.insert(2,list2)

# %%
print(list3)
# Out:
# [90, 87, ['king', 'queen', 'leaf', 1, 33, 'hii'], ['king', 'queen', 'leaf', 1, 33, 'hii'], ['king', 'queen', 'leaf', 1, 33, 'hii'], 56, 'hello', 54, 34, 23, 5, 3, 1, 'asus', 2, 3, 4]

# %%
# slicing inside list

# %%
list4 = [1,3,4,3,5,4]

# %%
list5 = ['hii','hello','sky','blue']

# %%
list4.insert(1,list5)

# %%
list4
# Out:
# [1, ['hii', 'hello', 'sky', 'blue'], 3, 4, 3, 5, 4]

# %%
print(list4[1][2:])
# Out:
# ['sky', 'blue']

# %%
name = 'Isha'

# %%
list4[1].append(name)

# %%
print(list4)
# Out:
# [1, ['hii', 'hello', 'sky', 'blue', 'Isha'], 3, 4, 3, 5, 4]

# %%
# practice

# %%
l = [3,4,2,9,88]

# %%
l.insert(2,'hii')

# %%
print(l)
# Out:
# [3, 4, 'hii', 2, 9, 88]

# %%
l2 = ['a','b','c']

# %%
l.insert(2,l2)

# %%
print(l)
# Out:
# [3, 4, ['a', 'b', 'c'], 'hii', 2, 9, 88]

# %%
l[2].remove('b')

# %%
print(l)
# Out:
# [3, 4, ['a', 'c'], 'hii', 2, 9, 88]

# %%
l.append('hello')

# %%
print(l)
# Out:
# [3, 4, ['a', 'c'], 'hii', 2, 9, 88, 'hello']

# %%
l[2].pop(1)
# Out:
# 'c'

# %%
print(l)
# Out:
# [3, 4, [], 'hii', 2, 9, 88, 'hello']

# %%
print(l)
# Out:
# [3, 4, [], 'hii', 2, 9, 88, 'hello']

# %%
l.pop(2)
# Out:
# []

# %%
print(l)
# Out:
# [3, 4, 'hii', 2, 9, 88, 'hello']

# %%
l.insert(3,l2)

# %%
print(l)
# Out:
# [3, 4, 'hii', [], 2, 9, 88, 'hello']

# %%
print(l2)
# Out:
# []

# %%
l3=['a','b','c']

# %%
l.insert(4,l3)

# %%
print(l)
# Out:
# [3, 4, 'hii', [], ['a', 'c'], 2, 9, 88, 'hello']

# %%
l[4].remove('b')

# %%
print(l)
# Out:
# [3, 4, 'hii', [], ['a', 'c'], 2, 9, 88, 'hello']

# %%
# if we insert copy instead of orignal list then the changes will only happen in the list where items are removed not orignal

# %%
l4 = [2,3,2,5,66]

# %%
l5 = ['a','b','c']

# %%
l4.insert(3,l5)

# %%
print(l4)
# Out:
# [2, 3, 2, ['a', 'c'], 5, 66]

# %%
print(l5)
# Out:
# ['a', 'c']

# %%
l6=[3,4,5,6,4,3,3,2]

# %%
l7 = ['a','b','c','d']

# %%
l6.insert(4,l7.copy())

# %%
print(l6)
# Out:
# [3, 4, 5, 6, ['a', 'b', 'c', 'd'], 4, 3, 3, 2]

# %%
l6[4].remove('c')

# %%
print(l6)
# Out:
# [3, 4, 5, 6, ['a', 'b', 'd'], 4, 3, 3, 2]

# %%
print(l7)
# Out:
# ['a', 'b', 'c', 'd']

# %%
# Datatype Tuple : immutable cannot be changed only few methods applied like count, index and even do type casting.Iteration is faster as compared to the list

# %%
tup=('king','queen','hello','sky')

# %%
type(tup)
# Out:
# tuple

# %%
print(tup)
# Out:
# ('king', 'queen', 'hello', 'sky')

# %%
tup.count('queen')
# Out:
# 1

# %%
tup.index('sky')
# Out:
# 3

# %%
l3 = [1,2,3,'a','b']

# %%
type(l3)
# Out:
# list

# %%
l3 = tuple(l3)

# %%
type(l3)
# Out:
# tuple

# %%
# Dictionary

# %%
student={'name': 'Isha','age': 21,'contact':78655436737}

# %%
print(student)
# Out:
# {'name': 'Isha', 'age': 21, 'contact': 78655436737}

# %%
print(student['name'])
# Out:
# Isha

# %%
student['name'] = 'Roy'

# %%
print(student)
# Out:
# {'name': 'Roy', 'age': 21, 'contact': 78655436737}

# %%
student['address'] = 'Mohali'

# %%
print(student)
# Out:
# {'name': 'Roy', 'age': 21, 'contact': 78655436737, 'address': 'Mohali'}

# %%
student.update({'name':'Rockey','address':'Chandigarh'})

# %%
print(student)
# Out:
# {'name': 'Rockey', 'age': 21, 'contact': 78655436737, 'address': 'Chandigarh'}

# %%
student.pop('age')
# Out:
# 21

# %%
print(student)
# Out:
# {'name': 'Rockey', 'contact': 78655436737, 'address': 'Chandigarh'}

# %%
del student['contact']

# %%
print(student)
# Out:
# {'name': 'Rockey', 'address': 'Chandigarh'}

# %%
student.update({'subject':'Data Science','age':24})

# %%
print(student)
# Out:
# {'name': 'Rockey', 'address': 'Chandigarh', 'subject': 'Data Science', 'age': 24}

# %%
# if key is there than it will give the res if not than we have passed the value not found msg
print(student.get('contact2','value not found'))
# Out:
# value not found

# %%
# Listed dictionary

# %%
Students={
    'st1':{
        'name':'Isha',
        'Rollno':22,
        'age':21},
        'st2' :{
        'name':'Ram',
        'Rollno':1,
        'age':32},
        'st3':{
        'name':'abc',
        'Rollno':34,
        'age':22}}

# %%
print(Students)
# Out:
# {'st1': {'name': 'Isha', 'Rollno': 22, 'age': 21}, 'st2': {'name': 'Ram', 'Rollno': 1, 'age': 32}, 'st3': {'name': 'abc', 'Rollno': 34, 'age': 22}}

# %%
print(Students['st3']['name'])
# Out:
# abc

# %%
print(len(Students))
# Out:
# 3

# %%
print(len(Students['st1']))
# Out:
# 3

# %%
Students.keys()
# Out:
# dict_keys(['st1', 'st2', 'st3'])

# %%
Students.values()
# Out:
# dict_values([{'name': 'Isha', 'Rollno': 22, 'age': 21}, {'name': 'Ram', 'Rollno': 1, 'age': 32}, {'name': 'abc', 'Rollno': 34, 'age': 22}])

# %%
Students.items()
# Out:
# dict_items([('st1', {'name': 'Isha', 'Rollno': 22, 'age': 21}), ('st2', {'name': 'Ram', 'Rollno': 1, 'age': 32}), ('st3', {'name': 'abc', 'Rollno': 34, 'age': 22})])

# %%
'stu3' in Students
# Out:
# False

# %%
'name' in Students['st2'].keys()
# Out:
# True

# %%
'name' in Students['st2'].values()
# Out:
# False

# %% [markdown]
# # DataType Set

# %%
set1 = {'n','hello','y','z',2,3}

# %%
print(set1)
# Out:
# {'y', 2, 3, 'n', 'z', 'hello'}

# %%
set1.pop()
# Out:
# 'y'

# %%
set1.update({6})

# %%
print(set1)
# Out:
# {2, 3, 'n', 6, 'z', 'hello'}

# %%
set1.remove(3)

# %%
print(set1)
# Out:
# {2, 'n', 6, 'z', 'hello'}

# %%
listA = list(set1) # error as i have made the list variable which is not allowed

# %%
listB = [1,2,4,5,5]

# %%
listC= set(listB)

# %%
type(listC)
# Out:
# set

# %%
name2 = 'isha'

# %%
print(name2.upper())
# Out:
# ISHA

# %%
print(name2)
# Out:
# isha

# %%
print(name2.capitalize())
# Out:
# Isha

# %%
sentence = '    hii     i am Isha   '

# %%
sentence.strip()
# Out:
# 'hii     i am Isha'

# %%
sentence = sentence.replace('Isha','Roy')

# %%
print(sentence)
# Out:
#     hii     i am Roy

# %%
sentence.strip()
# Out:
# 'hii     i am Roy'

# %%
s = " ".join(sentence.split())

# %%
print(s)
# Out:
# hii i am Roy

# %%
word = 'hello'

# %%
word.isalpha()
# Out:
# True

# %%
word.isdigit()
# Out:
# False

# %%
word1 = 'hello22'

# %%
word1.isalnum()
# Out:
# True
